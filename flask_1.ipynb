# %% [markdown]
# #### Q1.What is Flask Framework? What are the advantages of Flask Framework?
# * A Python library for developing web applications
# * Lightweight and simple to use
# * used for creating small web application

# %% [markdown]
# #### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.![Screenshot from 2023-03-20 23-32-40.png](attachment:40b9b908-59f8-4e96-b055-15ed005bae1e.png)

# %% [markdown]
# #### Q3. What is App routing in Flask? Why do we use app routes?
# * App routing is used to map the specific URL with the associated function that is intended to perform some task.

# %% [markdown]
# #### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details: Company Name: ABC Corporation, Location: India, Contact Detail: 999-999-9999.
# ##### Welcome message
# ![Screenshot from 2023-03-20 23-34-42.png](attachment:f14fd897-f0d1-4413-940e-1cdba9e5a537.png)
#
# ##### Address
# ![Screenshot from 2023-03-20 23-36-49.png](attachment:a66e95b7-b4e5-4d0a-94f9-556bc11eb7da.png)

# %% [markdown]
# #### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.
# * url_for() function is used in flask for URL Building.
# * Example:
# url_for('add', variable=foo)
# @app.route('/<variable>/add')
# def add(variable):
#     return "ADD"
