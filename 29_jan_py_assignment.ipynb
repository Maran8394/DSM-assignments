# %%
# 1. Who developed Python Programming Language?
# Answer: Python was developed by Guido van Rossum and first released in 1991.

# 2. Which type of Programming does Python support?
# Answer: Python supports multiple programming paradigms including procedural, object-oriented, and functional programming.

# 3. Is Python case sensitive when dealing with identifiers?
# Answer: Yes, Python is case sensitive. For example, `Variable` and `variable` would be considered different identifiers.

# 4. What is the correct extension of the Python file?
# Answer: The correct extension for a Python file is `.py`.

# 5. Is Python code compiled or interpreted?
# Answer: Python code is interpreted. Python code is executed line by line.

# 6. Name a few blocks of code used to define in Python language?
# Answer: Some blocks of code used in Python include:
# - Functions (`def function_name():`)
# - Classes (`class ClassName:`)
# - Loops (`for` and `while` loops)
# - Conditional statements (`if`, `elif`, `else`)

# 7. State a character used to give single-line comments in Python?
# Answer: The hash symbol `#` is used for single-line comments in Python.

# 8. Mention functions which can help us to find the version of python that we are currently working on?
# Answer: The `sys.version` and `platform.python_version()` functions can be used to find the Python version.
import sys
import platform
print(sys.version)
print(platform.python_version())

# 9. Python supports the creation of anonymous functions at runtime, using a construct called
# Answer: Python supports the creation of anonymous functions using a construct called `lambda`.

# 10. What does pip stand for python?
# Answer: `pip` stands for "Pip Installs Packages."

# 11. Mention a few built-in functions in python?
# Answer: Some built-in functions in Python include `print()`, `len()`, `type()`, `max()`, and `min()`.

# 12. What is the maximum possible length of an identifier in Python?
# Answer: The maximum length of an identifier in Python is not explicitly limited by the language itself, but practically, it can be very long (e.g., thousands of characters), depending on the implementation.

# 13. What are the benefits of using Python?
# Answer: Benefits of using Python include its simplicity and readability, extensive standard library, strong community support, and versatility in application (web development, data analysis, artificial intelligence, etc.).

# 14. How is memory managed in Python?
# Answer: Memory in Python is managed by the Python memory manager which includes built-in garbage collection and reference counting to automatically manage memory allocation and deallocation.

# 15. How to install Python on Windows and set path variables?
# Answer: To install Python on Windows:
# 1. Download the Python installer from the official website (https://www.python.org/).
# 2. Run the installer and make sure to check the box that says "Add Python to PATH."
# 3. Follow the installation prompts.
# To set path variables manually:
# 1. Go to System Properties > Environment Variables.
# 2. Under System variables, find the PATH variable and add the path to the Python executable (e.g., `C:\Python39\`).

# 16. Is indentation required in Python?
# Answer: Yes, indentation is required in Python. It is used to define the structure of code blocks, such as in loops, conditionals, and function definitions.
