# %% [markdown]
# #### Q1. Explain GET and POST methods.
# * GET - retrieve data from the server
# * POST - submit our data to the server

# %% [markdown]
# #### Q2. Why is request used in Flask?
# To access the incoming data in Flask, you have to use the request object. The request object holds all incoming data from the request, which includes the mimetype, referrer, IP address, raw data, HTTP method, and headers, among other things.

# %% [markdown]
# #### Q3.Why is redirect() used in Flask?
# redirects the user to another route with specified status code

# %% [markdown]
# #### Q4. What are templates in Flask? Why is the render_template() function used?
# * Templates : templates are the html pages.
# * render_template : is used the return the html page as response with data

# %% [markdown]
# #### Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.
#
# ![Screenshot from 2023-03-22 23-23-13.png](attachment:cac7ecb7-2276-43ca-838f-73420469c371.png)
